# %%
from evds import evdsAPI
evds= evdsAPI('YourAPIKey')
evds.main_categories
# Out:
# C:\Users\user\anaconda3\lib\site-packages\evds\__init__.py:42: FutureWarning: Could not cast to int32, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   main_categories_df = pd.DataFrame(main_categories_raw, dtype="int")[["CATEGORY_ID","TOPIC_TITLE_" + self.lang]]
#     CATEGORY_ID                                     TOPIC_TITLE_TR
# 0             1                                    PİYASA VERİLERİ
# 1             2                                             KURLAR
# 2             3                                FAİZ İSTATİSTİKLERİ
# 3             4                       PARA VE BANKA İSTATİSTİKLERİ
# 4             5                       MENKUL KIYMET İSTATİSTİKLERİ
# 5            12                             FİNANSAL İSTATİSTİKLER
# 6            13                              TCMB BİLANÇO VERİLERİ
# ...

# %%
evds.get_sub_categories(13)
# Out:
#    CATEGORY_ID DATAGROUP_CODE  \
# 0           13   bie_abanlbil
# 1           13    bie_mbblnch
# 2           13    bie_mbblnca
# 3           13     bie_abstc2
# 4           13     bie_abres2
# 5           13      bie_rkdrk
#
#                                       DATAGROUP_NAME
# 0            Merkez Bankası Analitik Bilanço(Bin TL)
# 1    Merkez Bankası Haftalık Vaziyeti (Yeni)(Bin TL)
# 2            Merkez Bankası Bilançosu (Yeni)(Bin TL)
# 3  Merkez Bankası Bilançosu-Stand By-18.01.2002 T...
# 4      Merkez Bankası Rezervleri (Milyon ABD Doları)
# 5  Reeskont Kredilerinin Döviz Rezervlerine Katki...

# %%
evds.get_series('bie_abanlbil')
# Out:
#     SERIE_CODE                                         SERIE_NAME  START_DATE
# 0    TP.AB.A01                                    A.AKTİF(Bin TL)  26-12-1980
# 1    TP.AB.A02                          A.1-DIŞ VARLIKLAR(Bin TL)  26-12-1980
# 2    TP.AB.A03                           A.2-İÇ VARLIKLAR(Bin TL)  26-12-1980
# 3    TP.AB.A04                        A.2A-Nakit İşlemler(Bin TL)  26-12-1980
# 4    TP.AB.A05                      A.2Aa-Hazine Borçları(Bin TL)  26-12-1980
# 5   TP.AB.A051                    A.2Aa1-Menkul Kıymetler(Bin TL)  24-11-2000
# 6   TP.AB.A052           A.2Aa1a-5 Kasım 2001 Öncesi DİBS(Bin TL)  24-11-2000
# 7   TP.AB.A053      A.2Aa1b-İkincil Piyasadan Alınan DİBS(Bin TL)  24-11-2000
# 8   TP.AB.A054                               A.2Aa2-Diğer(Bin TL)  24-11-2000
# 9    TP.AB.A06  A.2Ab-Bankacılık Sektörüne Açılan Nakit Kredil...  26-12-1980
# 10  TP.AB.A061       A.2Ac-TMSF'ye Kullandırılan Krediler(Bin TL)  24-11-2000
# ...

# %%
import seaborn as sns
import numpy as np
import pandas as pd

#fxab = USD/TRY rate and analytical balance sheet data frame

# TP_AB_A02 = Foreign Assets
# TP.DK.USD.A.YTL = USD/TRY Rate

#Load data and format the date column

fxab = evds.get_data(['TP.DK.USD.A.YTL','TP.AB.A02'], startdate="01-10-2019", enddate="20-01-2023")
fxab['Tarih'] = pd.to_datetime(fxab['Tarih'], dayfirst=True)
fxab['TP_AB_A02'] = fxab['TP_AB_A02'].ffill()
fxab['TP_DK_USD_A_YTL'] = fxab['TP_DK_USD_A_YTL'].ffill()

# Calculate the y-axis data
y = ((fxab["TP_AB_A02"]/fxab["TP_DK_USD_A_YTL"])/1000000)

# Create the plot
sns.lineplot(x="Tarih", y=y, data=fxab)

# Customize the plot
sns.set_style("whitegrid")
sns.set_context("notebook", font_scale=1.5)

# Rotate x-axis labels for readability
plt.xticks(rotation=45, ha='right')

# Add a title and labels
plt.title("Foreign Assets by USD", fontsize=20)
plt.xlabel("Date", fontsize=15)
plt.ylabel("Billion USD", fontsize=15)

# Show the plot
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\evds\__init__.py:180: FutureWarning: Could not cast to float64, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   df = pd.DataFrame(data, dtype="float")
